# %% [markdown]
# # Compact Visualization Documentation

# %% [markdown]
# **I. EDA.ipynb**

# %% [markdown]
# ![image.png](attachment:c946d8d2-47bf-4519-8da1-325351e9a580.png)
#
# ![image.png](attachment:081b3929-a577-4db0-a905-4c202c5128cb.png)
#
# ![image.png](attachment:4f506199-12c1-47d8-876d-1421f725166c.png)
#
# ![image.png](attachment:bfa27fb9-feb1-4f38-b458-ccf91e74aeb9.png)
#
# ![image.png](attachment:740f79e9-aba0-4d08-b19d-96dd2ef47e1d.png)

# %% [markdown]
# **II. BaselineModel.ipynb**

# %% [markdown]
# ![image.png](attachment:25fa3810-557b-4c6a-a34c-16f4e94e0baa.png)
#
# ![image.png](attachment:3131368a-5477-4ee4-bfc8-b4422b7f7993.png)

# %% [markdown]
# **III. BaseSVM.ipynb**

# %% [markdown]
# ![image.png](attachment:ee5e425f-66b3-450b-9b73-e0ea4ae0a753.png)
#
# ![image.png](attachment:f33b016d-b769-4632-9dab-b808ca5d00c3.png)

# %% [markdown]
# **VI. SVM_Smote.ipynb**

# %% [markdown]
# ![image.png](attachment:ad0022d6-96fd-4261-8a89-72e14dab65c9.png)
#
# ![image.png](attachment:82bc4250-4735-41af-9263-9470f5a0da0b.png)

# %% [markdown]
# **V. SGDModels.ipynb**

# %% [markdown]
# ![image.png](attachment:21aae44b-4653-4aa1-b6c1-de1bc24d3b24.png)
